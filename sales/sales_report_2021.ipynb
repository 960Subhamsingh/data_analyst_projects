# %%
import pandas as pd

# %%
df = pd.read_excel("E:/Datasets/Datasets/sales.xlsx", sheet_name='Orders')

# %%
df.head()

# %% [markdown]
# create a new column

# %%
df['Discount_Sales'] = df.apply(lambda row: row.Sales - row.Sales*.1, axis=1)
df.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...  Province   Region  \
# 0      0.04     Regular Air  -213.2500       38.94  ...   Nunavut  Nunavut
# 1      0.07  Delivery Truck   457.8100      208.16  ...   Nunavut  Nunavut
# 2      0.01     Regular Air    46.7075        8.69  ...   Nunavut  Nunavut
# 3      0.08     Regular Air  1198.9710      195.99  ...   Nunavut  Nunavut
# 4      0.08     Regular Air    30.9400       21.78  ...   Nunavut  Nunavut
#
# ...

# %%
df['New_Discount']= df.Sales-.15*df.Sales
df.head()

# %%
df.Sales.describe()
# Out:
# count     8399.000000
# mean      1775.878179
# std       3585.050525
# min          2.240000
# 25%        143.195000
# 50%        449.420000
# 75%       1709.320000
# max      89061.050000
# Name: Sales, dtype: float64

# %% [markdown]
# Higest_ product have sales of sales

# %%
a = [12,2,3,34,5,23]
['h' if(x>20) else 'l' for x in a]
# Out:
# ['l', 'l', 'l', 'h', 'l', 'h']

# %%
df['Sales_value'] = ['High value' if x>250 else 'low_ values' for x in df['Sales']]
df
# Out:
#       Row ID Order Date Order Priority  Order Quantity       Sales  Discount  \
# 0          1 2010-10-13            Low               6    261.5400      0.04
# 1         49 2012-10-01           High              49  10123.0200      0.07
# 2         50 2012-10-01           High              27    244.5700      0.01
# 3         80 2011-07-10           High              30   4965.7595      0.08
# 4         85 2010-08-28  Not Specified              19    394.2700      0.08
# ...      ...        ...            ...             ...         ...       ...
# 8394    7765 2010-08-09         Medium               8   1294.0400      0.05
# 8395    7766 2010-08-09         Medium              23    392.5700      0.04
# 8396    7906 2011-04-08  Not Specified              37    823.7800      0.03
# 8397    7907 2011-04-08  Not Specified               8    469.8375      0.00
# 8398    7914 2009-02-08           High              20   2026.0100      0.10
#
# ...

# %% [markdown]
# delete row and column in excel file

# %%
# remove column  from dataframe
dataframe =pd.DataFrame(df)
dataframe.drop("Row ID", axis=1, inplace=True)

# %%
df.drop("Row ID" , axis=1)

# %%
df.drop(['Order ID'], axis=1 , inplace= True)

# %%
df.drop(['Order ID','Row ID'], axis=1 , inplace= True)

# %%
df.drop([2,3], axis=0 , inplace= True)

# %% [markdown]
#  missing/ Null values

# %%
df.isnull()

# %%
df.isnull().iloc[0:25, :]

# %%
df.notnull().any().sum()
# Out:
# 22

# %% [markdown]
# find a uniue customer segment

# %%
df['Customer Segment'].unique()
# Out:
# array(['Small Business', 'Consumer', 'Corporate', 'Home Office'],
#       dtype=object)

# %%
df['Product Category'].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
category = {'Office Supplies':.06, 'Technology':.10, 'Furniture' :.12}

# %%
def dic(row_no , dic_val):
    return dic(row_no)

# %%
df['category_column'] = df["Product Category"].apply(dic, **args=(category))
df
# Out:
#   Cell In[123], line 1
#     df['category_column'] = df["Product Category"].apply(dic, **args=category)
#                                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# create dict to use  of customer Segemnt on sales data

# %%
seg = {'Small Business':.1, 'Consumer':.25, 'Home Office' : .15}

# %% [markdown]
# create a new column based  on category mappings

# %%
df['segment_tax'] = df['Customer Segment'].map(seg)
df
# Out:
#       Row ID Order Date Order Priority  Order Quantity       Sales  Discount  \
# 0          1 2010-10-13            Low               6    261.5400      0.04
# 1         49 2012-10-01           High              49  10123.0200      0.07
# 2         50 2012-10-01           High              27    244.5700      0.01
# 3         80 2011-07-10           High              30   4965.7595      0.08
# 4         85 2010-08-28  Not Specified              19    394.2700      0.08
# ...      ...        ...            ...             ...         ...       ...
# 8394    7765 2010-08-09         Medium               8   1294.0400      0.05
# 8395    7766 2010-08-09         Medium              23    392.5700      0.04
# 8396    7906 2011-04-08  Not Specified              37    823.7800      0.03
# 8397    7907 2011-04-08  Not Specified               8    469.8375      0.00
# 8398    7914 2009-02-08           High              20   2026.0100      0.10
#
# ...

# %% [markdown]
# read the excel file

# %%
d = pd.ExcelFile("E:/Datasets/Datasets/sales.xlsx")

# %%
d.parse('Orders')
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
# limit of rows import 
pay =pd.read_csv("C:/Users/hp/Desktop/payment.csv", nrows=12, sep=',', header=None, names=['I','H','L','G'])

# %%
pay
# Out:
#               I       H               L             G
# 0   customer_id  amount            mode  payment_date
# 1             1      60            Cash    2020-09-24
# 2             2      30     Credit Card    2020-04-27
# 3             3      90     Credit Card    2020-07-07
# 4             4      50      Debit Crad    2020-02-12
# 5             5      40  Mobile Payment    2020-11-20
# 6             6      40      Debit Crad    2021-06-28
# 7             7      10            Cash    2021-08-25
# 8             8      30  Mobile Payment    2021-06-17
# 9             9      80            Cash    2021-08-25
# 10           10      50  Mobile Payment    2021-11-03
# 11           11      70            Cash    2022-11-01

# %%
for key, value in pay.iterrows:
    print(key, value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 for key, value in pay.iterrows:
#       2     print(key, value)
#
# TypeError: 'method' object is not iterable

# %%
import dash
import dash_core_components as dcc
import plotly.graph_objects as go
import dash_html_components as html
import pandas as pd
import numpy as np
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9468\2164761633.py:2: UserWarning:
#
#
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#
# C:\Users\hp\AppData\Local\Temp\ipykernel_9468\2164761633.py:4: UserWarning:
#
#
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`

# %%
app = dash.Dash()

# %%
d = pd.ExcelFile("E:/Datasets/Datasets/sales.xlsx")

# %%
app.layout = html.Div([
    dcc.Graph{
        id="scatter_chart",figure={
            "data" : {
                
            }
        }
    }
])
